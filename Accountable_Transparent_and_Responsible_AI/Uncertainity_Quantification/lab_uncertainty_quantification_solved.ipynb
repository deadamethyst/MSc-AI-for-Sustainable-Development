# %% [markdown]
# ## Note:
# Adjusted from https://github.com/itsml/itsml/tree/master

# %% [markdown]
# # imports

# %%
from os import sep
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# Please refer to the ITSML github repo, to import specific pacakages used here

# %%
# !git clone https://github.com/itsml/itsml.git /content/itsml
# Out:
# fatal: destination path '/content/itsml' already exists and is not an empty directory.

# %%
import sys
sys.path.append('/content/itsml/Notebooks/uncertainty_quantification')

# %%
import Uncertainty as unc
import UncertaintyM as uncM
import Data.data_provider as dp

# %% [markdown]
# # Loading data
#
# We consider a standard setting of supervised learning, in which a learner is given access to a set of (i.i.d.) training data $\mathcal{D} \{ (\vec{x}_i , y_i )\}_{i=1}^N \subset \mathcal{X} \times \mathcal{Y}$, where $\mathcal{X}$ is an instance space and $\mathcal{Y}$ the set of outcomes that can be associated with an instance. In particular, we focus on the classification scenario, where $\mathcal{Y}=\{y_1, \ldots, y_K\}$ consists of a finite set of class labels, with binary classification ($\mathcal{Y} = \{0,1\}$) as an important special case.

# %%
data_name = "spambase"
features, target = dp.load_data(data_name)

# split and shuffel the data
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.4, shuffle=True, random_state=1)
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, shuffle=True, random_state=1)

# %% [markdown]
# # Train the ensemble
#
# In this section, given the data, we train a normal random forest classifier

# %%
model = RandomForestClassifier(max_depth=10, n_estimators=10, random_state=1)
model.fit(X_train, y_train) # remove keys when fiting the model

predictions = model.predict(X_test)
print("model test score = ", model.score(X_test, y_test))
# Out:
# model test score =  0.9217391304347826

# %% [markdown]
# # Uncertainty quantification
#
# In the literature on uncertainty, two inherently different sources of uncertainty are commonly distinguished, referred to as aleatoric and epistemic. Broadly speaking, aleatoric (aka statistical) uncertainty refers to the notion of randomness---coin flipping is a prototypical example.
# As opposed to this, epistemic (aka systematic) uncertainty refers to uncertainty caused by a lack of knowledge, i.e., it relates to the epistemic state of an agent. This uncertainty can in principle be reduced on the basis of additional information. In other words, epistemic uncertainty refers to the reducible part of the (total) uncertainty, whereas aleatoric uncertainty refers to the non-reducible part.
#
# Here the uncertainties are calculated for the test instances. For more detail on uncertainty calculation for random forest please see paper "Aleatoric and epistemic uncertainty with random forests."

# %%
total_uncertainty, epistemic_uncertainty, aleatoric_uncertainty = unc.model_uncertainty(model, X_test, X_train, y_train)

# %% [markdown]
# # Accuracy Rejection plot
#
# The empirical evaluation of methods for quantifying uncertainty is a non-trivial problem. In fact, unlike for the prediction of a target variable, the data does normally not contain information about any sort of ``ground truth'' uncertainty. What is often done, therefore, is to evaluate predicted uncertainties indirectly, that is, by assessing their usefulness for improved prediction and decision making. Adopting an approach of that kind, we produced accuracy-rejection curves, which depict the accuracy of a predictor as a function of the percentage of rejections: A classifier, which is allowed to abstain on a certain percentage $p$ of predictions, will predict on those $(1-p)$\,\% on which it feels most certain. Being able to quantify its own uncertainty well, it should improve its accuracy with increasing $p$, hence the accuracy-rejection curve should be monotone increasing (unlike a flat curve obtained for random abstention).

# %%
fig, axs = plt.subplots(1,3)
fig.set_figheight(3)
fig.set_figwidth(15)

avg_acc, avg_min, avg_max, avg_random ,steps = uncM.accuracy_rejection2(predictions.reshape((1,-1)), y_test.reshape((1,-1)), total_uncertainty.reshape((1,-1)))
axs[0].plot(steps, avg_acc*100)
axs[0].set_title("Total uncertainty rejection")

avg_acc, avg_min, avg_max, avg_random ,steps = uncM.accuracy_rejection2(predictions.reshape((1,-1)), y_test.reshape((1,-1)), epistemic_uncertainty.reshape((1,-1)))
axs[1].plot(steps, avg_acc*100)
axs[1].set_title("Epistemic uncertainty rejection")

avg_acc, avg_min, avg_max, avg_random ,steps = uncM.accuracy_rejection2(predictions.reshape((1,-1)), y_test.reshape((1,-1)), aleatoric_uncertainty.reshape((1,-1)))
axs[2].plot(steps, avg_acc*100)
axs[2].set_title("Aleatoric uncertainty rejection")

for i in range(3):
    axs[i].set(xlabel="Rejection %", ylabel="Accuracy %")

fig

# %% [markdown]
# # Summary
#
# In this lab, I investigated the ability of a Random Forest classifier to quantify predictive uncertainty and analyzed its utility through accuracy-rejection curves. These curves depict the model’s accuracy as a function of the percentage of predictions it abstains from, based on its own uncertainty estimates.
#
# I generarted accuracy-rejection curves corresponding to different types of uncertainty:
#
# Total Uncertainty Rejection reflects the model’s overall uncertainty, combining both epistemic (model-based) and aleatoric (data-based) components.
#
# Epistemic Uncertainty Rejection aptures the uncertainty due to lack of model knowledge. Predictions with higher epistemic uncertainty indicate areas where the model has less confidence due to limited information from the training data.
#
# Aleatoric Uncertainty Rejection measures uncertainty arising from inherent noise in the data, representing predictions that are intrinsically difficult to classify correctly regardless of the model.
#
# For each curve, the x-axis represents the percentage of predictions rejected (abstained from), and the y-axis shows the accuracy on the remaining predictions. A monotone increasing curve indicates that the model’s uncertainty estimates are informative: rejecting predictions with high uncertainty improves overall accuracy.
#
# **Observations**
#
# 1. All three curves exhibit a clear monotone increase in accuracy as the rejection percentage rises. This indicates that the Random Forest classifier is effectively identifying predictions it is uncertain about.
#
# 2. The epistemic uncertainty curve rises more steeply than the aleatoric curve, suggesting that the model is particularly good at identifying cases where its knowledge is limited.
#
# 3. The aleatoric uncertainty curve also shows improvement, though less pronounced, reflecting that some data points are inherently noisy and difficult to classify.
#
# By allowing the classifier to abstain on the least certain predictions, the model’s effective accuracy on the remaining predictions improves significantly. This demonstrates the utility of uncertainty estimation for selective prediction or risk-sensitive decision-making in real-world applications.
#
# The Random Forest classifier not only achieves high baseline accuracy but also provides meaningful uncertainty estimates. This is critical for scenarios where wrong predictions carry high costs, as the model can self-identify unreliable predictions and defer them for human review or additional analysis.
#
# **Conclusion**
#
# The accuracy-rejection curves confirm that our model can quantify its uncertainty in a meaningful way. Epistemic uncertainty is particularly informative for identifying low-confidence predictions, while aleatoric uncertainty highlights inherently noisy samples. Overall, this demonstrates that combining Random Forest predictions with uncertainty estimates can enhance model reliability and decision-making by selectively rejecting predictions with high uncertainty.
